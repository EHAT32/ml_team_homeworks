# %% [markdown]
# # EDA

# %% [markdown]
# В этом ноутбуке проведём исследовательский анализ различных датасетов с номерами машин. Датасеты будут взяты с Kaggle. Для большего разнообразия были найдены датасеты номеров из нескольких стран.

# %%
# %pip install opendatasets
# Out:
# ...
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# ...
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import opendatasets as od
import pandas as pd
import os

# %%
os.mkdir("datasets")
od.download("https://www.kaggle.com/datasets/evgrafovmaxim/nomeroff-russian-license-plates",data_dir="datasets")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/evgrafovmaxim/nomeroff-russian-license-plates
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 os.mkdir("datasets")
# ----> 2 od.download("https://www.kaggle.com/datasets/evgrafovmaxim/nomeroff-russian-license-plates",data_dir="datasets")
#
# File c:\Users\roman\miniconda3\Lib\site-packages\opendatasets\__init__.py:13, in download(dataset_id_or_url, data_dir, force, dry_run, **kwargs)
#      10 def download(dataset_id_or_url, data_dir='.', force=False, dry_run=False, **kwargs):
#      11     # Check for a Kaggle dataset URL
#      12     if is_kaggle_url(dataset_id_or_url):
# ---> 13         return download_kaggle_dataset(dataset_id_or_url, data_dir=data_dir, force=force, dry_run=dry_run)
#      15     # Check for Google Drive URL
#      16     if is_google_drive_url(dataset_id_or_url):
#
# ...
